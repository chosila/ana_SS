# %%
import os
import numpy as np
from collections import OrderedDict as OD
import enum
import math
#import uproot3 as upSroot
import uproot as uproot
import hist
import matplotlib.pyplot as plt
import mplhep as hep

mu_forS = 0.1 # 0.1 #1 # 0.1
sf_CL =  10 # 1000 #10 #1 # 10

sIpFile = '/eos/cms/store/user/ssawant/htoaa/analysis/20250109_gg0l_SByBScan/2018/analyze_htoaa_stage1.root'
sOpDir  = '/eos/cms/store/user/ssawant/htoaa/analysis/20250109_gg0l_SByBScan/2018/plots_sigGGH_mu%s_BgQCD' % (str(mu_forS).replace('.','p'))
#sOpDir  = '/eos/cms/store/user/ssawant/htoaa/analysis/20250109_gg0l_SByBScan/2018/plots_sigGGH_mu%s_BgTTHad' % (str(mu_forS).replace('.','p'))


if not os.path.exists(sOpDir):
    os.makedirs(sOpDir)
    
fIpFile = uproot.open(sIpFile)

# %%
#fIpFile.keys()
#fIpFile['evt'].keys()

# %%
#sTmp_ = 'evt/QCD_0bCat/hLeadingFatJetParticleNetMD_Hto4b_Haa01b_SR_central'
#sTmp_ in fIpFile.keys()

# %%
#fIpFile.keys()

# %%
sXRange = "xAxisRange"; sYRange = "yAxisRange";
sXLabel = 'xAxisLabel'; sYLabel = 'yAxisLabel';
sXAxisThrshType = 'XAxisThrshType'
sYAxisThrshType = 'YAxisThrshType'
sXAxisScale = 'xAxisScale'; sYAxisScale = 'yAxisScale'; 

printLevel = 0


era = 2018
luminosity = 54.54  #59.83
cmsWorkStatus='Work in Progress'


sData = "Data"
#MCBkg_list = ['QCD_bEnrich', 'QCD_bGen', 'QCD_Incl', 'TTJets_NLO', 'WJetsToQQ_HT', 'ZJetsToQQ_HT']
#MCBkg_list = ['QCD_bEnrich', 'QCD_bGen', 'QCD_Incl', 'TTJets_HT', 'WJetsToQQ_HT', 'ZJetsToQQ_HT']
#MCBkg_list = ['QCD_bEnrich', 'QCD_bGen', 'QCD_Incl', 'TTJets_Incl', 'WJetsToQQ_HT', 'ZJetsToQQ_HT']
#MCBkg_list = ['QCD_0bCat', 'QCD_1bCat', 'QCD_2bCat', 'QCD_3bCat', 'QCD_4bCat', 'QCD_5bAndMoreCat',  'TTJets_NLO', 'WJetsToQQ_HT', 'ZJetsToQQ_HT']
#MCBkg_list = ['QCD_0bCat', 'QCD_1bCat', 'QCD_2bCat', 'QCD_3bCat', 'QCD_4bCat', 'QCD_5bAndMoreCat',  'TTToHadronic_powheg', 'TTToSemiLeptonic_powheg', 'TTTo2L2Nu_powheg', 'WJetsToQQ_HT', 'ZJetsToQQ_HT']
#MCBkg_list = ['QCD_0bCat', 'QCD_1bCat', 'QCD_2bCat', 'QCD_3bCat', 'QCD_4bCat', 'QCD_5bAndMoreCat',  'TTToHadronic_powheg', 'TTToSemiLeptonic_powheg', 'TTTo2L2Nu_powheg',                 'ZJetsToQQ_HT' ]
#MCBkg_list = ['TTToHadronic_powheg', 'TTToSemiLeptonic_powheg', 'ZJetsToQQ_HT']
#MCBkg_list = [
#    'QCD_0bCat', 'QCD_1bCat', 'QCD_2bCat', 'QCD_3bCat', 'QCD_4bCat', 'QCD_5bAndMoreCat',  
#    'TTToHadronic_powheg', 'TTToSemiLeptonic_powheg', 'TTTo2L2Nu_powheg', "SingleTop", 
#    'ZJetsToQQ_HT', "DYJets_M-50_Incl_NLO", 
#    'WJetsToQQ_HT', 'WJetsToLNu_HT_LO',
#    'ZZ','WZ','WW', 'ZZZ','WZZ','WWZ','WWW',
#]
#MCBkg_list = [
#    "QCD_bEnr", "QCD_BGen", "QCD_Incl", 
#    "TT0l", "TT1l", "TT2l", 
#    "STop_t", "STbar_t", "ST_s_0l", "ST_s_1l", "STop_tW_Incl", "STbar_tW_Incl", "STop_tW_12l", "STbar_tW_12l", 
#    "ttZ", "ttW", "tZq", 
#    "Zqq", "Zvv", "Zll", "Wqq", "Wlv", 
#    "ZZ", "WZ", "WW", #"ZZZ", "WZZ", "WWZ", "WWW", 
#    #"ggH", #"VBFH", "VBFH_dipoleRecoilOn", "VBFWH_dipoleRecoilOn", 
#    #"WHbbqq", "WHbblv", 
#    #"ZH", #"ggZH", 
#    #"ttH", #"", "", "", 
#    #"", "", "", "", "", "",     
#]
MCBkg_list = [
    "QCD_bEnr", "QCD_BGen", #"QCD_Incl", 
    #"TT0l", #"TT1l", "TT2l", 
    #"STop_t", "STbar_t", "ST_s_0l", "ST_s_1l", "STop_tW_Incl", "STbar_tW_Incl", "STop_tW_12l", "STbar_tW_12l", 
    #"ttZ", "ttW", "tZq", 
    #"Zqq", "Zvv", "Zll", "Wqq", "Wlv", 
    #"ZZ", "WZ", "WW", #"ZZZ", "WZZ", "WWZ", "WWW", 
    #"ggH", #"VBFH", "VBFH_dipoleRecoilOn", "VBFWH_dipoleRecoilOn", 
    #"WHbbqq", "WHbblv", 
    #"ZH", #"ggZH", 
    #"ttH", #"", "", "", 
    #"", "", "", "", "", "",     
]
#MCSig_list = ['SUSY_GluGluH_01J_HToAATo4B_M-20_HPtAbv150']
#MCSig_list = ['SUSY_GluGluH_01J_HToAATo4B_M-60_HPtAbv150'] #['SUSY_GluGluH_01J_HToAATo4B_M-20_HPtAbv150', 'SUSY_GluGluH_01J_HToAATo4B_M-30_HPtAbv150', 'SUSY_GluGluH_01J_HToAATo4B_M-15_HPtAbv150', ]
#sLableSig = 'HToAATo4B_M-20'
#MCSig_dict = OD([
#    ('mA_12_15',    ['SUSY_GluGluH_01J_HToAATo4B_M-12_HPtAbv150', 'SUSY_GluGluH_01J_HToAATo4B_M-15_HPtAbv150']),
#    ('mA_25_30_35', ['SUSY_GluGluH_01J_HToAATo4B_M-25_HPtAbv150', 'SUSY_GluGluH_01J_HToAATo4B_M-30_HPtAbv150', 'SUSY_GluGluH_01J_HToAATo4B_M-35_HPtAbv150']),
#    ('mA_50_65',    ['SUSY_GluGluH_01J_HToAATo4B_M-50_HPtAbv150', 'SUSY_GluGluH_01J_HToAATo4B_M-60_HPtAbv150']),
#])
#MCSig_dict = OD([
#    ('mA_12_15',    ['SUSY_WH_WToAll_HToAATo4B_M-12_HPtAbv150', 'SUSY_WH_WToAll_HToAATo4B_M-15_HPtAbv150']),
#    ('mA_25_30_35', ['SUSY_WH_WToAll_HToAATo4B_M-25_HPtAbv150', 'SUSY_WH_WToAll_HToAATo4B_M-30_HPtAbv150', 'SUSY_WH_WToAll_HToAATo4B_M-35_HPtAbv150']),
#    ('mA_50_65',    ['SUSY_WH_WToAll_HToAATo4B_M-50_HPtAbv150', 'SUSY_WH_WToAll_HToAATo4B_M-60_HPtAbv150']),
#])
#MCSig_dict = OD([
#    ('mA_12_15',    ['SUSY_ZH_ZToAll_HToAATo4B_M-12_HPtAbv150', 'SUSY_ZH_ZToAll_HToAATo4B_M-15_HPtAbv150']),
#    ('mA_25_30_35', ['SUSY_ZH_ZToAll_HToAATo4B_M-25_HPtAbv150', 'SUSY_ZH_ZToAll_HToAATo4B_M-30_HPtAbv150', 'SUSY_ZH_ZToAll_HToAATo4B_M-35_HPtAbv150']),
#    ('mA_50_65',    ['SUSY_ZH_ZToAll_HToAATo4B_M-50_HPtAbv150', 'SUSY_ZH_ZToAll_HToAATo4B_M-60_HPtAbv150']),
#])
#MCSig_dict = OD([
#    ('mA_12_15',    ['SUSY_WH_WToAll_HToAATo4B_M-12_HPtAbv150', 'SUSY_WH_WToAll_HToAATo4B_M-15_HPtAbv150', 'SUSY_ZH_ZToAll_HToAATo4B_M-12_HPtAbv150', 'SUSY_ZH_ZToAll_HToAATo4B_M-15_HPtAbv150']),
#    ('mA_25_30_35', ['SUSY_WH_WToAll_HToAATo4B_M-25_HPtAbv150', 'SUSY_WH_WToAll_HToAATo4B_M-30_HPtAbv150', 'SUSY_WH_WToAll_HToAATo4B_M-35_HPtAbv150', 'SUSY_ZH_ZToAll_HToAATo4B_M-25_HPtAbv150', 'SUSY_ZH_ZToAll_HToAATo4B_M-30_HPtAbv150', 'SUSY_ZH_ZToAll_HToAATo4B_M-35_HPtAbv150']),
#    ('mA_50_65',    ['SUSY_WH_WToAll_HToAATo4B_M-50_HPtAbv150', 'SUSY_WH_WToAll_HToAATo4B_M-60_HPtAbv150', 'SUSY_ZH_ZToAll_HToAATo4B_M-50_HPtAbv150', 'SUSY_ZH_ZToAll_HToAATo4B_M-60_HPtAbv150']),
#])
#MCSig_dict = OD([
#    ('mA_12_15',    ['ttHtoaato4b_mA_12', 'ttHtoaato4b_mA_15',]),
#    ('mA_25_30_35', ['ttHtoaato4b_mA_25', 'ttHtoaato4b_mA_30', 'ttHtoaato4b_mA_35',]),
#    ('mA_50_60',    ['ttHtoaato4b_mA_50', 'ttHtoaato4b_mA_60', ]),
#])
MCSig_dict = OD([
    ('mA_12_15',    ['ggHtoaato4b_mA_12', 'ggHtoaato4b_mA_15',]),
#    ('mA_25_30_35', ['ggHtoaato4b_mA_25', 'ggHtoaato4b_mA_30', 'ggHtoaato4b_mA_35',]),
#    ('mA_50_60',    ['ggHtoaato4b_mA_50', 'ggHtoaato4b_mA_60', ]),
#    ('mA_GtEq20',   [
#        'ggHtoaato4b_mA_20', 
#        'ggHtoaato4b_mA_25', 
#        'ggHtoaato4b_mA_30', 
#        'ggHtoaato4b_mA_35',
#        'ggHtoaato4b_mA_40', 
#        'ggHtoaato4b_mA_45', 
#        'ggHtoaato4b_mA_50', 
#        'ggHtoaato4b_mA_55', 
#        'ggHtoaato4b_mA_60',        
#    ]),
])

systematics_list = ['Nom'] # ['central']
systematics_forData = 'noweight'
#selectionTags = ['SRWP80'] # ['SR'] # ['sel_leadingFatJetMSoftDrop']
#selectionTags = ['tt0l_ge1NonHFatJet_0BExtra_SRWP80', 'tt0l_ge1NonHFatJet_1BExtra_SRWP80', 'tt0l_ge1NonHFatJet_ge2BExtra_SRWP80', 'tt0l_0NonHFatJet_ge2B_SRWP80']
#selectionTags = ['tt0l_ge1NonHFatJet_0BExtra_SRWP80']
selectionTags = ['gg0lIncl']
SignalEfficiencyThresholdsForTaggerWPs     = [] #[0.8, 0.6, 0.4]
BackgroundMistagRateThresholdsForTaggerWPs = [5e-2, 4e-2, 3e-2, 2e-2, 1e-2, 5e-3, 4e-3, 3e-3, 2e-3, 1e-3] #[2e-2, 1e-2, 5e-3, 1e-3]

class ThrshTypes(enum.Enum):
    LowerThrsh = 'LowerThreshold'
    UpperThrsh = 'UpperThreshold'


histograms_dict = OD([
    #("hLeadingFatJetMass", {sXLabel: 'Leading FatJet mass [GeV]', sYLabel: 'Events', sXRange: [50, 250], sYRange: [1e-2, 1e8]})
    #("hLeadingFatJetMass", {sXLabel: 'Leading FatJet mass [GeV]', sYLabel: 'Events', sXRange: [50, 250]}),
    
    #("", {sXLabel: '', sYLabel: 'Events', sXRange: []}),
    
    #("hCutFlow", {sXLabel: 'hCutFlow', sYLabel: 'Events'}),
    #("hCutFlowWeighted", {sXLabel: 'hCutFlowWeighted', sYLabel: 'Events'}),

    #("hPV_npvs_beforeSel", {sXLabel: 'No. of primary vertices before selection', sYLabel: 'Events', sXRange: [0, 100] }),
    #("hPV_npvsGood_beforeSel", {sXLabel: 'No. of good primary vertices before selection', sYLabel: 'Events', sXRange: [0, 100] }),

    ("hLeadingFatJetDeepTagMD_HbbvsQCD", {sXLabel: 'hLeadingFatJetDeepTagMD_HbbvsQCD', sYLabel: 'Events', sXRange: [0, 1], sXAxisThrshType: ThrshTypes.LowerThrsh }),
    ("hLeadingFatJet_nSV", {sXLabel: 'hLeadingFatJet_nSV', sYLabel: 'Events', sXRange: [-0.5, 10.5], sXAxisThrshType: ThrshTypes.LowerThrsh }),

    ("hLeadingFatJetDeepTagMD_H4qvsQCD", {sXLabel: 'hLeadingFatJetDeepTagMD_H4qvsQCD', sYLabel: 'Events', sXRange: [0, 1], sXAxisThrshType: ThrshTypes.LowerThrsh }),
    ("hLeadingFatJetDeepTagMD_HbbvsQCD", {sXLabel: 'hLeadingFatJetDeepTagMD_HbbvsQCD', sYLabel: 'Events', sXRange: [0, 1], sXAxisThrshType: ThrshTypes.LowerThrsh }),
    ("hLeadingFatJetDeepTagMD_ZHbbvsQCD", {sXLabel: 'hLeadingFatJetDeepTagMD_ZHbbvsQCD', sYLabel: 'Events', sXRange: [0, 1], sXAxisThrshType: ThrshTypes.LowerThrsh }),
    ("hLeadingFatJetDeepTagMD_ZHccvsQCD", {sXLabel: 'hLeadingFatJetDeepTagMD_ZHccvsQCD', sYLabel: 'Events', sXRange: [0, 1], sXAxisThrshType: ThrshTypes.UpperThrsh }),
    ("hLeadingFatJetDeepTagMD_bbvsLight", {sXLabel: 'hLeadingFatJetDeepTagMD_bbvsLight', sYLabel: 'Events', sXRange: [0, 1], sXAxisThrshType: ThrshTypes.LowerThrsh }),
    
    
    ("hLeadingFatJetN2b1", {sXLabel: 'hLeadingFatJetN2b1', sYLabel: 'Events', sXRange: [0, 3], sXAxisThrshType: ThrshTypes.LowerThrsh }),
    ("hLeadingFatJetN3b1", {sXLabel: 'hLeadingFatJetN3b1', sYLabel: 'Events', sXRange: [0, 5], sXAxisThrshType: ThrshTypes.LowerThrsh }),

    ("hLeadingFatJetN2b1", {sXLabel: 'hLeadingFatJetN2b1', sYLabel: 'Events', sXRange: [0, 3], sXAxisThrshType: ThrshTypes.UpperThrsh }),
    ("hLeadingFatJetN3b1", {sXLabel: 'hLeadingFatJetN3b1', sYLabel: 'Events', sXRange: [0, 5], sXAxisThrshType: ThrshTypes.UpperThrsh }),

    ("hLeadingFatJetTau1", {sXLabel: 'hLeadingFatJetTau1', sYLabel: 'Events', sXRange: [0, 1], sXAxisThrshType: ThrshTypes.LowerThrsh }),
    ("hLeadingFatJetTau2", {sXLabel: 'hLeadingFatJetTau2', sYLabel: 'Events', sXRange: [0, 1], sXAxisThrshType: ThrshTypes.LowerThrsh }),
    ("hLeadingFatJetTau3", {sXLabel: 'hLeadingFatJetTau3', sYLabel: 'Events', sXRange: [0, 1], sXAxisThrshType: ThrshTypes.LowerThrsh }),
    ("hLeadingFatJetTau4", {sXLabel: 'hLeadingFatJetTau4', sYLabel: 'Events', sXRange: [0, 1], sXAxisThrshType: ThrshTypes.LowerThrsh }),
    
    ("hLeadingFatJetTau4by3", {sXLabel: 'hLeadingFatJetTau4by3', sYLabel: 'Events', sXRange: [0, 1], sXAxisThrshType: ThrshTypes.LowerThrsh }),
    ("hLeadingFatJetTau3by2", {sXLabel: 'hLeadingFatJetTau3by2', sYLabel: 'Events', sXRange: [0, 1], sXAxisThrshType: ThrshTypes.LowerThrsh }),    
    ("hLeadingFatJetTau2by1", {sXLabel: 'hLeadingFatJetTau2by1', sYLabel: 'Events', sXRange: [0, 1], sXAxisThrshType: ThrshTypes.LowerThrsh }),

    ("hLeadingFatJetTau4by3", {sXLabel: 'hLeadingFatJetTau4by3', sYLabel: 'Events', sXRange: [0, 1], sXAxisThrshType: ThrshTypes.UpperThrsh }),
    ("hLeadingFatJetTau3by2", {sXLabel: 'hLeadingFatJetTau3by2', sYLabel: 'Events', sXRange: [0, 1], sXAxisThrshType: ThrshTypes.UpperThrsh }),    
    ("hLeadingFatJetTau2by1", {sXLabel: 'hLeadingFatJetTau2by1', sYLabel: 'Events', sXRange: [0, 1], sXAxisThrshType: ThrshTypes.UpperThrsh }),
    
    
    ("hLeadingFatJetParticleNetMD_XbbOverQCD", {sXLabel: 'hLeadingFatJetParticleNetMD_XbbOverQCD', sYLabel: 'Events', sXRange: [0, 1], sXAxisThrshType: ThrshTypes.LowerThrsh }),
    ("hLeadingFatJetParticleNetMD_XccOverQCD", {sXLabel: 'hLeadingFatJetParticleNetMD_XccOverQCD', sYLabel: 'Events', sXRange: [0, 1], sXAxisThrshType: ThrshTypes.UpperThrsh }),
    ("hLeadingFatJetParticleNetMD_XqqOverQCD", {sXLabel: 'hLeadingFatJetParticleNetMD_XqqOverQCD', sYLabel: 'Events', sXRange: [0, 1], sXAxisThrshType: ThrshTypes.UpperThrsh }),
    ("hLeadingFatJetParticleNet_mass", {sXLabel: 'hLeadingFatJetParticleNet_mass', sYLabel: 'Events', sXRange: [0, 300], sXAxisThrshType: ThrshTypes.LowerThrsh }),
    
    ("hLeadingFatJet_nSubJets", {sXLabel: 'hLeadingFatJet_nSubJets', sYLabel: 'Events', sXRange: [-0.5, 10.5], sXAxisThrshType: ThrshTypes.LowerThrsh }),
    ("hLeadingFatJet_nSubJets_bTag_L", {sXLabel: 'hLeadingFatJet_nSubJets_bTag_L', sYLabel: 'Events', sXRange: [-0.5, 10.5], sXAxisThrshType: ThrshTypes.LowerThrsh }),
    ("hLeadingFatJet_nSubJets_bTag_M", {sXLabel: 'hLeadingFatJet_nSubJets_bTag_M', sYLabel: 'Events', sXRange: [-0.5, 10.5], sXAxisThrshType: ThrshTypes.LowerThrsh }),
    
    ("hLeadingFatJet_nSV", {sXLabel: 'hLeadingFatJet_nSV', sYLabel: 'Events', sXRange: [-0.5, 10.5], sXAxisThrshType: ThrshTypes.LowerThrsh }),
        
    ("hMET_pT", {sXLabel: 'hMET_pT', sYLabel: 'Events', sXRange: [0, 1000], sXAxisThrshType: ThrshTypes.UpperThrsh }),
    ("hMET_sumEt", {sXLabel: 'hMET_sumEt', sYLabel: 'Events', sXRange: [0, 1], sXAxisThrshType: ThrshTypes.UpperThrsh }),

    

    ("hLeadingFatJetDeepTagMD_HbbvsQCD_vs_LeadingFatJet_nSV", {sXLabel: 'hLeadingFatJetDeepTagMD_HbbvsQCD', sYLabel: 'LeadingFatJet_nSV', sXRange: [0, 1], sYRange: [-0.5, 10.5], sXAxisThrshType: ThrshTypes.LowerThrsh, sYAxisThrshType: ThrshTypes.LowerThrsh }),
    ("hLeadingFatJetDeepTagMD_HbbvsQCD_vs_LeadingFatJetN2b1", {sXLabel: 'hLeadingFatJetDeepTagMD_HbbvsQCD', sYLabel: 'LeadingFatJetN2b1', sXRange: [0, 1], sYRange: [0, 3], sXAxisThrshType: ThrshTypes.LowerThrsh, sYAxisThrshType: ThrshTypes.LowerThrsh }),
    ("hLeadingFatJetDeepTagMD_HbbvsQCD_vs_LeadingFatJetN3b1", {sXLabel: 'hLeadingFatJetDeepTagMD_HbbvsQCD', sYLabel: 'LeadingFatJetN3b1', sXRange: [0, 1], sYRange: [0, 5], sXAxisThrshType: ThrshTypes.LowerThrsh, sYAxisThrshType: ThrshTypes.LowerThrsh }),
    ("hLeadingFatJetDeepTagMD_HbbvsQCD_vs_LeadingFatJetTau1", {sXLabel: 'hLeadingFatJetDeepTagMD_HbbvsQCD', sYLabel: 'LeadingFatJetTau1', sXRange: [0, 1], sYRange: [0, 1], sXAxisThrshType: ThrshTypes.LowerThrsh, sYAxisThrshType: ThrshTypes.LowerThrsh }),
    ("hLeadingFatJetDeepTagMD_HbbvsQCD_vs_LeadingFatJetTau2", {sXLabel: 'hLeadingFatJetDeepTagMD_HbbvsQCD', sYLabel: 'LeadingFatJetTau2', sXRange: [0, 1], sYRange: [0, 1], sXAxisThrshType: ThrshTypes.LowerThrsh, sYAxisThrshType: ThrshTypes.LowerThrsh }),
    ("hLeadingFatJetDeepTagMD_HbbvsQCD_vs_LeadingFatJetTau3", {sXLabel: 'hLeadingFatJetDeepTagMD_HbbvsQCD', sYLabel: 'LeadingFatJetTau3', sXRange: [0, 1], sYRange: [0, 1], sXAxisThrshType: ThrshTypes.LowerThrsh, sYAxisThrshType: ThrshTypes.LowerThrsh }),
    ("hLeadingFatJetDeepTagMD_HbbvsQCD_vs_LeadingFatJetTau4", {sXLabel: 'hLeadingFatJetDeepTagMD_HbbvsQCD', sYLabel: 'LeadingFatJetTau4', sXRange: [0, 1], sYRange: [0, 1], sXAxisThrshType: ThrshTypes.LowerThrsh, sYAxisThrshType: ThrshTypes.LowerThrsh }),
    ("hLeadingFatJetDeepTagMD_HbbvsQCD_vs_LeadingFatJetTau4by3", {sXLabel: 'hLeadingFatJetDeepTagMD_HbbvsQCD', sYLabel: 'LeadingFatJetTau4by3', sXRange: [0, 1], sYRange: [0, 1], sXAxisThrshType: ThrshTypes.LowerThrsh, sYAxisThrshType: ThrshTypes.LowerThrsh }),
    ("hLeadingFatJetDeepTagMD_HbbvsQCD_vs_LeadingFatJetTau3by2", {sXLabel: 'hLeadingFatJetDeepTagMD_HbbvsQCD', sYLabel: 'LeadingFatJetTau3by2', sXRange: [0, 1], sYRange: [0, 1], sXAxisThrshType: ThrshTypes.LowerThrsh, sYAxisThrshType: ThrshTypes.LowerThrsh }),
    ("hLeadingFatJetDeepTagMD_HbbvsQCD_vs_LeadingFatJetTau2by1", {sXLabel: 'hLeadingFatJetDeepTagMD_HbbvsQCD', sYLabel: 'LeadingFatJetTau2by1', sXRange: [0, 1], sYRange: [0, 1], sXAxisThrshType: ThrshTypes.LowerThrsh, sYAxisThrshType: ThrshTypes.LowerThrsh }),
    ("hLeadingFatJetDeepTagMD_HbbvsQCD_vs_LeadingFatJetDeepTagMD_ZHbbvsQCD", {sXLabel: 'hLeadingFatJetDeepTagMD_HbbvsQCD', sYLabel: 'LeadingFatJetDeepTagMD_ZHbbvsQCD', sXRange: [0, 1], sYRange: [0, 1], sXAxisThrshType: ThrshTypes.LowerThrsh, sYAxisThrshType: ThrshTypes.LowerThrsh }),
    ("hLeadingFatJetDeepTagMD_HbbvsQCD_vs_LeadingFatJetDeepTagMD_bbvsLight", {sXLabel: 'hLeadingFatJetDeepTagMD_HbbvsQCD', sYLabel: 'LeadingFatJetDeepTagMD_bbvsLight', sXRange: [0, 1], sYRange: [0, 1], sXAxisThrshType: ThrshTypes.LowerThrsh, sYAxisThrshType: ThrshTypes.LowerThrsh }),
    ("hLeadingFatJetDeepTagMD_HbbvsQCD_vs_LeadingFatJet_nSubJets", {sXLabel: 'hLeadingFatJetDeepTagMD_HbbvsQCD', sYLabel: 'LeadingFatJet_nSubJets', sXRange: [-0.5, 10.5], sYRange: [0, 1], sXAxisThrshType: ThrshTypes.LowerThrsh, sYAxisThrshType: ThrshTypes.LowerThrsh }),
    ("hLeadingFatJetDeepTagMD_HbbvsQCD_vs_LeadingFatJet_nSubJets_bTag_L", {sXLabel: 'hLeadingFatJetDeepTagMD_HbbvsQCD', sYLabel: 'LeadingFatJet_nSubJets_bTag_L', sXRange: [-0.5, 10.5], sYRange: [0, 1], sXAxisThrshType: ThrshTypes.LowerThrsh, sYAxisThrshType: ThrshTypes.LowerThrsh }),
    ("hLeadingFatJetDeepTagMD_HbbvsQCD_vs_LeadingFatJet_nSubJets_bTag_M", {sXLabel: 'hLeadingFatJetDeepTagMD_HbbvsQCD', sYLabel: 'LeadingFatJet_nSubJets_bTag_M', sXRange: [-0.5, 10.5], sYRange: [0, 1], sXAxisThrshType: ThrshTypes.LowerThrsh, sYAxisThrshType: ThrshTypes.LowerThrsh }),
    ("hLeadingFatJetDeepTagMD_HbbvsQCD_vs_MET_pT", {sXLabel: 'hLeadingFatJetDeepTagMD_HbbvsQCD', sYLabel: 'MET_pT', sXRange: [0, 1], sYRange: [0, 1000], sXAxisThrshType: ThrshTypes.LowerThrsh, sYAxisThrshType: ThrshTypes.LowerThrsh }),
    ("hLeadingFatJetDeepTagMD_HbbvsQCD_vs_MET_sumEt", {sXLabel: 'hLeadingFatJetDeepTagMD_HbbvsQCD', sYLabel: '', sXRange: [0, 1], sYRange: [0, 1], sXAxisThrshType: ThrshTypes.LowerThrsh, sYAxisThrshType: ThrshTypes.LowerThrsh }),
    
    ("hLeadingFatJetParticleNetMD_XbbOverQCD_vs_LeadingFatJet_nSV", {sXLabel: 'hLeadingFatJetParticleNetMD_XbbOverQCD', sYLabel: 'LeadingFatJet_nSV', sXRange: [0, 1], sYRange: [-0.5, 10.5], sXAxisThrshType: ThrshTypes.LowerThrsh, sYAxisThrshType: ThrshTypes.LowerThrsh }),
    ("hLeadingFatJetParticleNetMD_XbbOverQCD_vs_LeadingFatJetN2b1", {sXLabel: 'hLeadingFatJetParticleNetMD_XbbOverQCD', sYLabel: 'LeadingFatJetN2b1', sXRange: [0, 1], sYRange: [0, 3], sXAxisThrshType: ThrshTypes.LowerThrsh, sYAxisThrshType: ThrshTypes.LowerThrsh }),
    ("hLeadingFatJetParticleNetMD_XbbOverQCD_vs_LeadingFatJetN3b1", {sXLabel: 'hLeadingFatJetParticleNetMD_XbbOverQCD', sYLabel: 'LeadingFatJetN3b1', sXRange: [0, 1], sYRange: [0, 5], sXAxisThrshType: ThrshTypes.LowerThrsh, sYAxisThrshType: ThrshTypes.LowerThrsh }),
    ("hLeadingFatJetParticleNetMD_XbbOverQCD_vs_LeadingFatJetTau1", {sXLabel: 'hLeadingFatJetParticleNetMD_XbbOverQCD', sYLabel: 'LeadingFatJetTau1', sXRange: [0, 1], sYRange: [0, 1], sXAxisThrshType: ThrshTypes.LowerThrsh, sYAxisThrshType: ThrshTypes.LowerThrsh }),
    ("hLeadingFatJetParticleNetMD_XbbOverQCD_vs_LeadingFatJetTau2", {sXLabel: 'hLeadingFatJetParticleNetMD_XbbOverQCD', sYLabel: 'LeadingFatJetTau2', sXRange: [0, 1], sYRange: [0, 1], sXAxisThrshType: ThrshTypes.LowerThrsh, sYAxisThrshType: ThrshTypes.LowerThrsh }),
    ("hLeadingFatJetParticleNetMD_XbbOverQCD_vs_LeadingFatJetTau3", {sXLabel: 'hLeadingFatJetParticleNetMD_XbbOverQCD', sYLabel: 'LeadingFatJetTau3', sXRange: [0, 1], sYRange: [0, 1], sXAxisThrshType: ThrshTypes.LowerThrsh, sYAxisThrshType: ThrshTypes.LowerThrsh }),
    ("hLeadingFatJetParticleNetMD_XbbOverQCD_vs_LeadingFatJetTau4", {sXLabel: 'hLeadingFatJetParticleNetMD_XbbOverQCD', sYLabel: 'LeadingFatJetTau4', sXRange: [0, 1], sYRange: [0, 1], sXAxisThrshType: ThrshTypes.LowerThrsh, sYAxisThrshType: ThrshTypes.LowerThrsh }),
    ("hLeadingFatJetParticleNetMD_XbbOverQCD_vs_LeadingFatJetTau4by3", {sXLabel: 'hLeadingFatJetParticleNetMD_XbbOverQCD', sYLabel: 'LeadingFatJetTau4by3', sXRange: [0, 1], sYRange: [0, 1], sXAxisThrshType: ThrshTypes.LowerThrsh, sYAxisThrshType: ThrshTypes.LowerThrsh }),
    ("hLeadingFatJetParticleNetMD_XbbOverQCD_vs_LeadingFatJetTau3by2", {sXLabel: 'hLeadingFatJetParticleNetMD_XbbOverQCD', sYLabel: 'LeadingFatJetTau3by2', sXRange: [0, 1], sYRange: [0, 1], sXAxisThrshType: ThrshTypes.LowerThrsh, sYAxisThrshType: ThrshTypes.LowerThrsh }),
    ("hLeadingFatJetParticleNetMD_XbbOverQCD_vs_LeadingFatJetTau2by1", {sXLabel: 'hLeadingFatJetParticleNetMD_XbbOverQCD', sYLabel: 'LeadingFatJetTau2by1', sXRange: [0, 1], sYRange: [0, 1], sXAxisThrshType: ThrshTypes.LowerThrsh, sYAxisThrshType: ThrshTypes.LowerThrsh }),
    ("hLeadingFatJetParticleNetMD_XbbOverQCD_vs_LeadingFatJet_nSubJets", {sXLabel: 'hLeadingFatJetParticleNetMD_XbbOverQCD', sYLabel: 'LeadingFatJet_nSubJets', sXRange: [-0.5, 10.5], sYRange: [0, 1], sXAxisThrshType: ThrshTypes.LowerThrsh, sYAxisThrshType: ThrshTypes.LowerThrsh }),
    ("hLeadingFatJetParticleNetMD_XbbOverQCD_vs_LeadingFatJet_nSubJets_bTag_L", {sXLabel: 'hLeadingFatJetParticleNetMD_XbbOverQCD', sYLabel: 'LeadingFatJet_nSubJets_bTag_L', sXRange: [-0.5, 10.5], sYRange: [0, 1], sXAxisThrshType: ThrshTypes.LowerThrsh, sYAxisThrshType: ThrshTypes.LowerThrsh }),
    ("hLeadingFatJetParticleNetMD_XbbOverQCD_vs_LeadingFatJet_nSubJets_bTag_M", {sXLabel: 'hLeadingFatJetParticleNetMD_XbbOverQCD', sYLabel: 'LeadingFatJet_nSubJets_bTag_M', sXRange: [-0.5, 10.5], sYRange: [0, 1], sXAxisThrshType: ThrshTypes.LowerThrsh, sYAxisThrshType: ThrshTypes.LowerThrsh }),
    ("hLeadingFatJetParticleNetMD_XbbOverQCD_vs_MET_pT", {sXLabel: 'hLeadingFatJetParticleNetMD_XbbOverQCD', sYLabel: 'MET_pT', sXRange: [0, 1], sYRange: [0, 1000], sXAxisThrshType: ThrshTypes.LowerThrsh, sYAxisThrshType: ThrshTypes.LowerThrsh }),
    ("hLeadingFatJetParticleNetMD_XbbOverQCD_vs_MET_sumEt", {sXLabel: 'hLeadingFatJetParticleNetMD_XbbOverQCD', sYLabel: '', sXRange: [0, 1], sYRange: [0, 1], sXAxisThrshType: ThrshTypes.LowerThrsh, sYAxisThrshType: ThrshTypes.LowerThrsh }),



])

xRangeTagger = [0, 1]
xRangeTagger1 = [0.85, 1] #[0.9, 1]
histograms_dict = OD([
    ("hLeadingBtagFatJetPtOverLeadingFatJetPt", {sXLabel: 'hLeadingBtagFatJetPtOverLeadingFatJetPt', sYLabel: 'Events', sXRange: [0, 1.1], sXAxisThrshType: ThrshTypes.LowerThrsh }),

    #("hLeadingFatJetParticleNetMD_Hto4b_Haa01b", {sXLabel: 'hLeadingFatJetParticleNetMD_Hto4b_Haa01b', sYLabel: 'Events', sXRange: xRangeTagger, sXAxisThrshType: ThrshTypes.LowerThrsh }),
    #("hLeadingFatJetParticleNetMD_Hto4b_Haa2b", {sXLabel: 'hLeadingFatJetParticleNetMD_Hto4b_Haa2b', sYLabel: 'Events', sXRange: xRangeTagger, sXAxisThrshType: ThrshTypes.LowerThrsh }),
    ("hLeadingFatJetParticleNetMD_Hto4b_Haa3b", {sXLabel: 'hLeadingFatJetParticleNetMD_Hto4b_Haa3b', sYLabel: 'Events', sXRange: xRangeTagger, sXAxisThrshType: ThrshTypes.LowerThrsh }),
    ("hLeadingFatJetParticleNetMD_Hto4b_Haa4b", {sXLabel: 'hLeadingFatJetParticleNetMD_Hto4b_Haa4b', sYLabel: 'Events', sXRange: xRangeTagger, sXAxisThrshType: ThrshTypes.LowerThrsh }),
    #("hLeadingFatJetParticleNetMD_Hto4b_QCD0b", {sXLabel: 'hLeadingFatJetParticleNetMD_Hto4b_QCD0b', sYLabel: 'Events', sXRange: xRangeTagger, sXAxisThrshType: ThrshTypes.LowerThrsh }),
    #("hLeadingFatJetParticleNetMD_Hto4b_QCD1b", {sXLabel: 'hLeadingFatJetParticleNetMD_Hto4b_QCD1b', sYLabel: 'Events', sXRange: xRangeTagger, sXAxisThrshType: ThrshTypes.LowerThrsh }),
    #("hLeadingFatJetParticleNetMD_Hto4b_QCD2b", {sXLabel: 'hLeadingFatJetParticleNetMD_Hto4b_QCD2b', sYLabel: 'Events', sXRange: xRangeTagger, sXAxisThrshType: ThrshTypes.LowerThrsh }),
    #("hLeadingFatJetParticleNetMD_Hto4b_QCD3b", {sXLabel: 'hLeadingFatJetParticleNetMD_Hto4b_QCD3b', sYLabel: 'Events', sXRange: xRangeTagger, sXAxisThrshType: ThrshTypes.LowerThrsh }),
    #("hLeadingFatJetParticleNetMD_Hto4b_QCD4b", {sXLabel: 'hLeadingFatJetParticleNetMD_Hto4b_QCD4b', sYLabel: 'Events', sXRange: xRangeTagger, sXAxisThrshType: ThrshTypes.LowerThrsh }),
    ("hLeadingFatJetParticleNetMD_Hto4b_binaryLF_Haa4b", {sXLabel: 'hLeadingFatJetParticleNetMD_Hto4b_binaryLF_Haa4b', sYLabel: 'Events', sXRange: xRangeTagger1, sXAxisThrshType: ThrshTypes.LowerThrsh }),
    #("hLeadingFatJetParticleNetMD_Hto4b_binaryLF_QCDlf", {sXLabel: 'hLeadingFatJetParticleNetMD_Hto4b_binaryLF_QCDlf', sYLabel: 'Events', sXRange: xRangeTagger, sXAxisThrshType: ThrshTypes.LowerThrsh }),
    ("hLeadingFatJetParticleNetMD_Hto4b_binary_Haa4b", {sXLabel: 'hLeadingFatJetParticleNetMD_Hto4b_binary_Haa4b', sYLabel: 'Events', sXRange: xRangeTagger1, sXAxisThrshType: ThrshTypes.LowerThrsh }),
    #("hLeadingFatJetParticleNetMD_Hto4b_binary_QCD", {sXLabel: 'hLeadingFatJetParticleNetMD_Hto4b_binary_QCD', sYLabel: 'Events', sXRange: xRangeTagger, sXAxisThrshType: ThrshTypes.LowerThrsh }),
    ("hLeadingFatJetParticleNetMD_Hto4b_Haa34b", {sXLabel: 'hLeadingFatJetParticleNetMD_Hto4b_Haa34b', sYLabel: 'Events', sXRange: xRangeTagger1, sXAxisThrshType: ThrshTypes.LowerThrsh }),
    
    ("hLeadingFatJetParticleNetMD_Hto4b_binary_Haa4b_avg", {sXLabel: 'hLeadingFatJetParticleNetMD_Hto4b_binary_Haa4b_avg', sYLabel: 'Events', sXRange: xRangeTagger1, sXAxisThrshType: ThrshTypes.LowerThrsh }),
    ("hLeadingFatJetParticleNetMD_Hto4b_Haa4b_avg", {sXLabel: 'hLeadingFatJetParticleNetMD_Hto4b_Haa4b_avg', sYLabel: 'Events', sXRange: xRangeTagger1, sXAxisThrshType: ThrshTypes.LowerThrsh }),
    #("hLeadingFatJetParticleNetMD_Hto4b_QCD01234b", {sXLabel: 'hLeadingFatJetParticleNetMD_Hto4b_QCD01234b', sYLabel: 'Events', sXRange: xRangeTagger, sXAxisThrshType: ThrshTypes.LowerThrsh }),
    #("hLeadingFatJetParticleNetMD_Hto4b_binary_QCD_avg", {sXLabel: 'hLeadingFatJetParticleNetMD_Hto4b_binary_QCD_avg', sYLabel: 'Events', sXRange: xRangeTagger, sXAxisThrshType: ThrshTypes.LowerThrsh }),
    #("hLeadingFatJetParticleNetMD_Hto4b_QCD_avg", {sXLabel: 'hLeadingFatJetParticleNetMD_Hto4b_QCD_avg', sYLabel: 'Events', sXRange: xRangeTagger, sXAxisThrshType: ThrshTypes.LowerThrsh }),
    ("hLeadingFatJetParticleNetMD_Hto4b_Htoaa4bOverQCD", {sXLabel: 'hLeadingFatJetParticleNetMD_Hto4b_Htoaa4bOverQCD', sYLabel: 'Events', sXRange: xRangeTagger1, sXAxisThrshType: ThrshTypes.LowerThrsh }),
    
    ("hLeadingFatJetParticleNetMD_Hto4b_Htoaa34bOverQCD", {sXLabel: 'hLeadingFatJetParticleNetMD_Hto4b_Htoaa34bOverQCD', sYLabel: 'Events', sXRange: xRangeTagger1, sXAxisThrshType: ThrshTypes.LowerThrsh }),
    #("hLeadingFatJetParticleNetMD_Hto4b_binaryLF_Htoaa4bOverQCD", {sXLabel: 'hLeadingFatJetParticleNetMD_Hto4b_binaryLF_Htoaa4bOverQCD', sYLabel: 'Events', sXRange: xRangeTagger1, sXAxisThrshType: ThrshTypes.LowerThrsh }),
    #("hLeadingFatJetParticleNetMD_Hto4b_binary_Htoaa4bOverQCD", {sXLabel: 'hLeadingFatJetParticleNetMD_Hto4b_binary_Htoaa4bOverQCD', sYLabel: 'Events', sXRange: xRangeTagger1, sXAxisThrshType: ThrshTypes.LowerThrsh }),
    ("hLeadingFatJetParticleNetMD_Hto4b_binary_Htoaa4bOverQCD_avg", {sXLabel: 'hLeadingFatJetParticleNetMD_Hto4b_binary_Htoaa4bOverQCD_avg', sYLabel: 'Events', sXRange: xRangeTagger1, sXAxisThrshType: ThrshTypes.LowerThrsh }),
    ("hLeadingFatJetParticleNetMD_Hto4b_Htoaa4bOverQCD_avg", {sXLabel: 'hLeadingFatJetParticleNetMD_Hto4b_Htoaa4bOverQCD_avg', sYLabel: 'Events', sXRange: xRangeTagger1, sXAxisThrshType: ThrshTypes.LowerThrsh }),
    
    ("hLeadingFatJetParticleNetMD_XbbOverQCD", {sXLabel: 'hLeadingFatJetParticleNetMD_XbbOverQCD', sYLabel: 'Events', sXRange: [0.8, 1], sXAxisThrshType: ThrshTypes.LowerThrsh }),
    ("hLeadingFatJetDeepTagMD_ZHbbvsQCD", {sXLabel: 'hLeadingFatJetDeepTagMD_ZHbbvsQCD', sYLabel: 'Events', sXRange: [0.8, 1], sXAxisThrshType: ThrshTypes.LowerThrsh }),
    ("hLeadingFatJetZHbb_plus_Xbb", {sXLabel: 'hLeadingFatJetZHbb_plus_Xbb', sYLabel: 'Events', sXRange: [0, 2.], sXAxisThrshType: ThrshTypes.LowerThrsh, sYAxisScale: 'log' }),
    #   
    
])

#histograms_dict = OD([
##    #("hLeadingFatJetParticleNetMD_XbbOverQCD", {sXLabel: 'hLeadingFatJetParticleNetMD_XbbOverQCD', sYLabel: 'Events', sXRange: [0, 1], sXAxisThrshType: ThrshTypes.LowerThrsh }),
#    ("hLeadingFatJetParticleNetMD_Hto4b_binaryLF_Haa4b", {sXLabel: 'hLeadingFatJetParticleNetMD_Hto4b_binaryLF_Haa4b', sYLabel: 'Events', sXRange: xRangeTagger1, sXAxisThrshType: ThrshTypes.LowerThrsh }),        
#])

histograms_dict = OD([
    ("hdPhi_LeadingFJ_LeadingNonHto4bFJ", {sXLabel: 'hdPhi_LeadingFJ_LeadingNonHto4bFJ', sYLabel: 'Events', sXRange: [0, 3.14], sXAxisThrshType: ThrshTypes.LowerThrsh }),        
    ("hLeadingNonHto4bFatJetDeepTag_WvsQCD", {sXLabel: 'hLeadingNonHto4bFatJetDeepTag_WvsQCD', sYLabel: 'Events', sXRange: xRangeTagger, sXAxisThrshType: ThrshTypes.LowerThrsh }),        
    ("hLeadingNonHto4bFatJetDeepTag_ZvsQCD", {sXLabel: 'hLeadingNonHto4bFatJetDeepTag_ZvsQCD', sYLabel: 'Events', sXRange: xRangeTagger, sXAxisThrshType: ThrshTypes.LowerThrsh }),        
    ("hLeadingNonHto4bFatJetDeepTag_VvsQCD_max", {sXLabel: 'hLeadingNonHto4bFatJetDeepTag_VvsQCD_max', sYLabel: 'Events', sXRange: xRangeTagger, sXAxisThrshType: ThrshTypes.LowerThrsh }),        
    ("hLeadingNonHto4bFatJetDeepTag_W", {sXLabel: 'hLeadingNonHto4bFatJetDeepTag_W', sYLabel: 'Events', sXRange: xRangeTagger, sXAxisThrshType: ThrshTypes.LowerThrsh }),        
    ("hLeadingNonHto4bFatJetDeepTag_Z", {sXLabel: 'hLeadingNonHto4bFatJetDeepTag_Z', sYLabel: 'Events', sXRange: xRangeTagger, sXAxisThrshType: ThrshTypes.LowerThrsh }),        
    ("hLeadingNonHto4bFatJetDeepTag_V_max", {sXLabel: 'hLeadingNonHto4bFatJetDeepTag_V_max', sYLabel: 'Events', sXRange: xRangeTagger, sXAxisThrshType: ThrshTypes.LowerThrsh }),        
    ("hLeadingNonHto4bFatJetDeepTag_WZvsQCD", {sXLabel: 'hLeadingNonHto4bFatJetDeepTag_WZvsQCD', sYLabel: 'Events', sXRange: xRangeTagger, sXAxisThrshType: ThrshTypes.LowerThrsh }),        
    ("hLeadingNonHto4bFatJetDeepTag_WZvsQCD2", {sXLabel: 'hLeadingNonHto4bFatJetDeepTag_WZvsQCD2', sYLabel: 'Events', sXRange: xRangeTagger, sXAxisThrshType: ThrshTypes.LowerThrsh }),        
    ("hLeadingNonHto4bFatJetParticleNet_WvsQCD", {sXLabel: 'hLeadingNonHto4bFatJetParticleNet_WvsQCD', sYLabel: 'Events', sXRange: xRangeTagger, sXAxisThrshType: ThrshTypes.LowerThrsh }),        
    ("hLeadingNonHto4bFatJetParticleNet_ZvsQCD", {sXLabel: 'hLeadingNonHto4bFatJetParticleNet_ZvsQCD', sYLabel: 'Events', sXRange: xRangeTagger, sXAxisThrshType: ThrshTypes.LowerThrsh }),        
    ("hLeadingNonHto4bFatJetPNet_VvsQCD_max", {sXLabel: 'hLeadingNonHto4bFatJetPNet_VvsQCD_max', sYLabel: 'Events', sXRange: xRangeTagger, sXAxisThrshType: ThrshTypes.LowerThrsh }),        
    ("hLeadingNonHto4bFatJetPNet_W", {sXLabel: 'hLeadingNonHto4bFatJetPNet_W', sYLabel: 'Events', sXRange: xRangeTagger, sXAxisThrshType: ThrshTypes.LowerThrsh }),        
    ("hLeadingNonHto4bFatJetPNet_Z", {sXLabel: 'hLeadingNonHto4bFatJetPNet_Z', sYLabel: 'Events', sXRange: xRangeTagger, sXAxisThrshType: ThrshTypes.LowerThrsh }),        
    ("hLeadingNonHto4bFatJetPNet_V_max", {sXLabel: 'hLeadingNonHto4bFatJetPNet_V_max', sYLabel: 'Events', sXRange: xRangeTagger, sXAxisThrshType: ThrshTypes.LowerThrsh }),        
    ("hLeadingNonHto4bFatJetPNet_WZvsQCD", {sXLabel: 'hLeadingNonHto4bFatJetPNet_WZvsQCD', sYLabel: 'Events', sXRange: xRangeTagger, sXAxisThrshType: ThrshTypes.LowerThrsh }),        
    ("hLeadingNonHto4bFatJetPNet_WZvsQCD2", {sXLabel: 'hLeadingNonHto4bFatJetPNet_WZvsQCD2', sYLabel: 'Events', sXRange: xRangeTagger, sXAxisThrshType: ThrshTypes.LowerThrsh }),        
      
])

histograms_dict = OD([
    ("hLeadingFatJetPNet_X4b_v1_Haa4b_vs_QCD", {sXLabel: 'hLeadingFatJetPNet_X4b_v1_Haa4b_vs_QCD', sYLabel: 'Events', sXRange: xRangeTagger1, sXAxisThrshType: ThrshTypes.LowerThrsh }),
    ("hLeadingFatJetPNet_X4b_v2a_Haa4b_score", {sXLabel: 'hLeadingFatJetPNet_X4b_v2a_Haa4b_score', sYLabel: 'Events', sXRange: xRangeTagger1, sXAxisThrshType: ThrshTypes.LowerThrsh }),
    ("hLeadingFatJetPNet_X4b_v2b_Haa4b_score", {sXLabel: 'hLeadingFatJetPNet_X4b_v2b_Haa4b_score', sYLabel: 'Events', sXRange: xRangeTagger1, sXAxisThrshType: ThrshTypes.LowerThrsh }),
    #("hLeadingFatJetPNet_X4b_v2ab_Haa4b_score", {sXLabel: 'hLeadingFatJetPNet_X4b_v2ab_Haa4b_score', sYLabel: 'Events', sXRange: [1.5, 2], sXAxisThrshType: ThrshTypes.LowerThrsh }),
    ("hLeadingFatJetPNet_X4b_v2ab55_Haa4b_score", {sXLabel: 'hLeadingFatJetPNet_X4b_v2ab55_Haa4b_score', sYLabel: 'Events', sXRange: xRangeTagger1, sXAxisThrshType: ThrshTypes.LowerThrsh }),
    ("hLeadingFatJetPNet_X4b_v2ab64_Haa4b_score", {sXLabel: 'hLeadingFatJetPNet_X4b_v2ab64_Haa4b_score', sYLabel: 'Events', sXRange: xRangeTagger1, sXAxisThrshType: ThrshTypes.LowerThrsh }),
     
])


'''
# ttH Hadronic scan
histograms_dict = OD([
    ("hLeadingNonHto4bFatJetParticleNet_WvsQCD", {sXLabel: 'hLeadingNonHto4bFatJetParticleNet_WvsQCD', sYLabel: 'Events', sXRange: xRangeTagger, sXAxisThrshType: ThrshTypes.LowerThrsh }),        
    ("hLeadingNonHto4bFatJetPNet_VvsQCD_max", {sXLabel: 'hLeadingNonHto4bFatJetPNet_VvsQCD_max', sYLabel: 'Events', sXRange: xRangeTagger, sXAxisThrshType: ThrshTypes.LowerThrsh }),        
    ("hLeadingNonHto4bFatJetPNet_W", {sXLabel: 'hLeadingNonHto4bFatJetPNet_W', sYLabel: 'Events', sXRange: xRangeTagger, sXAxisThrshType: ThrshTypes.LowerThrsh }),        
    ("hLeadingNonHto4bFatJetPNet_V_max", {sXLabel: 'hLeadingNonHto4bFatJetPNet_V_max', sYLabel: 'Events', sXRange: xRangeTagger, sXAxisThrshType: ThrshTypes.LowerThrsh }),        
    ("hLeadingNonHto4bFatJetPNet_WZvsQCD", {sXLabel: 'hLeadingNonHto4bFatJetPNet_WZvsQCD', sYLabel: 'Events', sXRange: xRangeTagger, sXAxisThrshType: ThrshTypes.LowerThrsh }),        
    ("hLeadingNonHto4bFatJetPNet_WZvsQCD2", {sXLabel: 'hLeadingNonHto4bFatJetPNet_WZvsQCD2', sYLabel: 'Events', sXRange: xRangeTagger, sXAxisThrshType: ThrshTypes.LowerThrsh }),        
    ("hLeadingNonHto4bFatJetPNet_TvsQCD", {sXLabel: 'hLeadingNonHto4bFatJetPNet_TvsQCD', sYLabel: 'Events', sXRange: xRangeTagger, sXAxisThrshType: ThrshTypes.LowerThrsh }),        
    ("hPtSumAK4JetsCentral_NonoverlapLeadingFatJets", {sXLabel: 'hPtSumAK4JetsCentral_NonoverlapLeadingFatJets', sYLabel: 'Events', sXRange: [100, 1400], sXAxisThrshType: ThrshTypes.LowerThrsh }),        
      
])
'''

#histograms_dict = OD([
#    ("hLeadingNonHto4bFatJetPNet_TvsQCD", {sXLabel: 'hLeadingNonHto4bFatJetPNet_TvsQCD', sYLabel: 'Events', sXRange: xRangeTagger, sXAxisThrshType: ThrshTypes.LowerThrsh }),        
#      
#])

histograms_dict
# Out:
# OrderedDict([('hLeadingFatJetPNet_X4b_v1_Haa4b_vs_QCD',
#               {'xAxisLabel': 'hLeadingFatJetPNet_X4b_v1_Haa4b_vs_QCD',
#                'yAxisLabel': 'Events',
#                'xAxisRange': [0.85, 1],
#                'XAxisThrshType': <ThrshTypes.LowerThrsh: 'LowerThreshold'>}),
#              ('hLeadingFatJetPNet_X4b_v2a_Haa4b_score',
#               {'xAxisLabel': 'hLeadingFatJetPNet_X4b_v2a_Haa4b_score',
#                'yAxisLabel': 'Events',
#                'xAxisRange': [0.85, 1],
#                'XAxisThrshType': <ThrshTypes.LowerThrsh: 'LowerThreshold'>}),
#              ('hLeadingFatJetPNet_X4b_v2b_Haa4b_score',
#               {'xAxisLabel': 'hLeadingFatJetPNet_X4b_v2b_Haa4b_score',
#                'yAxisLabel': 'Events',
#                'xAxisRange': [0.85, 1],
#                'XAxisThrshType': <ThrshTypes.LowerThrsh: 'LowerThreshold'>}),
#              ('hLeadingFatJetPNet_X4b_v2ab_Haa4b_score',
# ...

# %%
def GetHist1DMaxValue(h):
    bin_yMax = np.argmax( h.values() )
    x_yMax = h.axes[0].centers[bin_yMax]
    y_max = h.values()[bin_yMax] 
    return  x_yMax, y_max

def GetHist1DMinValue(h):
    bin_yMin = np.argmin( h.values() )
    if printLevel >= 8:    print(f"{bin_yMin = }")
    x_yMin = h.axes[0].centers[bin_yMin]
    y_min = h.values()[bin_yMin] 
    return  x_yMin, y_min

def getNonzeroMin(array_):
    return np.min(array_[np.nonzero(array_)])

def FindHist1DBin(h, x):
    xEdges = h.axes[0].edges
    if x > xEdges[-1]: return len(h.axes[0].centers) - 1

    xBin = np.argwhere(np.logical_and( (x >= xEdges[0:-1]), (x < xEdges[1:])  )) # output: array([[1]])
    xBin = xBin[0][0] # 
    if printLevel >= 10:    print(f"{x = }, {xBin = }, {list(xEdges) = }")
    return xBin

# %%
def scan_SByB_over_H1D(hSig, hBkgTot, xAxisThrshType, xAxisRange, SEffiThrshs=[0.8, 0.6, 0.4], BEffiThrshs=[2e-2, 1e-2, 5e-3]):
    #print(f"scan_SByB_over_H1D():: {xAxisThrshType = }  \nhSig.axes[0].centers ({len(hSig.axes[0].centers)}): {hSig.axes[0].centers} \nhSig.axes[0].edges ({len(hSig.axes[0].edges)}): {hSig.axes[0].edges} ")
    #print(f"hSig.values() ({len(hSig.values())}) ({type(hSig.values())}): {hSig.values()} ")
    #print(f"hBkgTot.values() ({len(hBkgTot.values())}) ({type(hBkgTot.values())}): {hBkgTot.values()} ")

    '''xBinRangeMin = 0
    xBinRangeMax = (len(hSig.axes[0].edges) - 1)
    if xAxisRange:
        #xBinRangeMax = 0
        xBinRangeMin = FindHist1DBin(hSig, xAxisRange[0])
        xBinRangeMax = FindHist1DBin(hSig, xAxisRange[1])
    '''
    xBinFix = (len(hSig.axes[0].edges) - 1) if xAxisThrshType == ThrshTypes.LowerThrsh else 0
    #print(f"{xBinFix = }")
    
    #print(f"hSig.axes[0] ({type(hSig.axes[0])}): {hSig.axes[0]}")
    
    hSEffi          = hist.Hist(hSig.axes[0])
    hBEffi          = hist.Hist(hSig.axes[0])
    hSByB           = hist.Hist(hSig.axes[0])    
    hSBySB          = hist.Hist(hSig.axes[0])
    hSignificanceZ  = hist.Hist(hSig.axes[0])
    hCL             = hist.Hist(hSig.axes[0])
    

    #print(f"hSByB ({type(hSByB)}): {hSByB}")
    #print(f"hSByB.values() ({len(hSByB.values())}) ({type(hSByB.values())}): {hSByB.values()} ")
    
    S_total = np.sum(hSig   .values())
    B_total = np.sum(hBkgTot.values())
    for xBinFloat in range(len(hSig.axes[0].edges) - 1):
        xBinLowerEdge = hSig.axes[0].edges[xBinFloat]
        xBinUpperEdge = hSig.axes[0].edges[xBinFloat+1]
        xBinLower = min(xBinFloat, xBinFix)
        xBinUpper = max(xBinFloat, xBinFix)
        S = np.sum(hSig   .values()[xBinLower : xBinUpper])
        B = np.sum(hBkgTot.values()[xBinLower : xBinUpper])
        SEffi          = S / S_total
        BEffi          = B / B_total #1 - (B / B_total)
        Sprime         = mu_forS * S
        SByB           = Sprime / math.sqrt(B) if B > 0 else 0
        SBySB          = Sprime / math.sqrt(Sprime+B) if (Sprime+B) > 0 else 0
        SignificanceZ  = math.sqrt( (2*(Sprime+B)*math.log(1 + (Sprime/B))) - (2*Sprime) ) if B > 0 else 0
        #CL             = sf_CL * 2 * ( (1/S) + (math.sqrt(B+1)/S) )   if S > S_total*1e-4 else getNonzeroMin(hCL.values())*2
        #CL             = sf_CL * 2 * ( (1/S) + (math.sqrt(B+1)/S) )   if B > 1 and S > 0 else getNonzeroMin(hCL.values())*2
        CL             = sf_CL * 2 * ( (1/S) + (math.sqrt(B+1)/S) )   if S > 0 and xBinUpperEdge < xAxisRange[1] else getNonzeroMin(hCL.values())*2
        #CL             = 100 * 2 * ( (1/S) + (math.sqrt(B+1)/S) )   if S >2 else 5  
        #print(f"x:{hSig.axes[0].centers[xBinFloat]}, xBinFloat: {xBinFloat}, [{xBinLower}, {xBinUpper}], S: {S} ({hSig.values()[xBinLower : xBinUpper].shape}) {hSig.values()[xBinLower : xBinUpper]}, B: {B}  ({hBkgTot.values()[xBinLower : xBinUpper].shape}), SByB: {SByB} ")
        if printLevel >= 5:    
            print(f" {hSig.axes[0].centers[xBinFloat]} ({xBinFloat}) [{hSig.axes[0].edges[xBinFloat]}, {hSig.axes[0].edges[xBinFloat+1]}] {S = }, {B = }, {SByB = }, {SBySB = }, {SignificanceZ = }, {CL = }, ")
        hSEffi[xBinFloat]         = SEffi
        hBEffi[xBinFloat]         = BEffi
        hSByB[xBinFloat]          = SByB 
        hSBySB[xBinFloat]         = SBySB
        hSignificanceZ[xBinFloat] = SignificanceZ
        hCL[xBinFloat]            = CL
        

    bin_SByBMax = np.argmax( hSByB.values() )
    x_SByBMax = hSByB.axes[0].centers[bin_SByBMax]
    SByB_max = hSByB.values()[bin_SByBMax]

    x_SEffi_map = {}
    x_SEffi_SByB_map = {}
    for SEffiThrsh in SEffiThrshs + BEffiThrshs:
        if SEffiThrsh in SEffiThrshs:
            hEffi_toUse = hSEffi
        elif SEffiThrsh in BEffiThrshs:
            hEffi_toUse = hBEffi

        if xAxisThrshType == ThrshTypes.LowerThrsh:
            bin_SEffiPt = np.argmax( hEffi_toUse.values() < SEffiThrsh ) # return aidx for first true
        else:
            bin_SEffiPt = np.argmax( hEffi_toUse.values() > SEffiThrsh )

        x_SEffiPt             = hSEffi.axes[0].centers[bin_SEffiPt]
        SEffi_SEffiPt         = hSEffi.values()[bin_SEffiPt]
        BEffi_SEffiPt         = hBEffi.values()[bin_SEffiPt]
        SByB_SEffiPt          = hSByB.values()[bin_SEffiPt]
        SBySB_SEffiPt         = hSBySB.values()[bin_SEffiPt]
        SignificanceZ_SEffiPt = hSignificanceZ.values()[bin_SEffiPt]
        CL_SEffiPt            = hCL.values()[bin_SEffiPt]

        x_SEffi_map[SEffiThrsh] = x_SEffiPt
        #x_SEffi_SByB_map[x_SEffiPt] = [SEffiThrsh, BEffi_SEffiPt, SByB_SEffiPt, SBySB_SEffiPt, SignificanceZ_SEffiPt, CL_SEffiPt]
        x_SEffi_SByB_map[x_SEffiPt] = [SEffi_SEffiPt, BEffi_SEffiPt, SByB_SEffiPt, SBySB_SEffiPt, SignificanceZ_SEffiPt, CL_SEffiPt]
        #print(f" hSEffi.values() < SEffiThrsh: { hSEffi.values() < SEffiThrsh}")
        #print(f"{bin_SEffiPt = }, {hSEffi.axes[0].centers[bin_SEffiPt] = }")
    
    #print(f"hSByB ({type(hSByB)}): {hSByB}")
    #print(f"hSByB.values() ({len(hSByB.values())}) ({type(hSByB.values())}): {hSByB.values()} ")

    #print(f"SByBMax: {np.max(hSByB.values())}, {bin_SByBMax = }, {x_SByBMax = }")

    #return hSByB, SByB_max, x_SByBMax, hSEffi, x_SEffi_map, x_SEffi_SByB_map
    return hSEffi, hBEffi, hSByB, hSBySB, hSignificanceZ, hCL, SByB_max, x_SByBMax, x_SEffi_map, x_SEffi_SByB_map

# %%
def scan_SByB_over_H2D(hSig, hBkgTot, xAxisThrshType, yAxisThrshType):
    if len(hSig.axes) != 2:
        print(f"scan_SByB_over_H2D():: len(hSig.axes) != 2 \t\t **** ERROR **** \nAborting...\n")
        exit(0)

    #print(f"scan_SByB_over_H2D():: {xAxisThrshType = }  \nhSig.axes[0].centers ({len(hSig.axes[0].centers)}): {hSig.axes[0].centers} \nhSig.axes[0].edges ({len(hSig.axes[0].edges)}): {hSig.axes[0].edges} ")
    #print(f"\nhSig.axes[1].centers ({len(hSig.axes[1].centers)}): {hSig.axes[1].centers} \nhSig.axes[1].edges ({len(hSig.axes[1].edges)}): {hSig.axes[1].edges} ")
    #print(f"hSig.values() ({len(hSig.values())}) ({type(hSig.values())}): {hSig.values().tolist()} ")
    #print(f"hBkgTot.values() ({len(hBkgTot.values())}) ({type(hBkgTot.values())}): {hBkgTot.values()} ")

    xBinFix = (len(hSig.axes[0].edges) - 1) if xAxisThrshType == ThrshTypes.LowerThrsh else 0
    yBinFix = (len(hSig.axes[1].edges) - 1) if xAxisThrshType == ThrshTypes.LowerThrsh else 0
    #print(f"{xBinFix = }, {yBinFix = }")
    
    #print(f"hSig.axes[0] ({type(hSig.axes[0])}): {hSig.axes[0]}")
    

    hSByB = hist.Hist(hSig.axes[0], hSig.axes[1])

    #print(f"hSByB ({type(hSByB)}): {hSByB}")
    #print(f"hSByB.values() ({len(hSByB.values())}) ({type(hSByB.values())}): {hSByB.values()} ")
    
    S_total = np.sum(hSig   .values())
    for xBinFloat in range(len(hSig.axes[0].edges) - 1):        
        xBinLower = min(xBinFloat, xBinFix)
        xBinUpper = max(xBinFloat, xBinFix)

        for yBinFloat in range(len(hSig.axes[1].edges) - 1):        
            yBinLower = min(yBinFloat, yBinFix)
            yBinUpper = max(yBinFloat, yBinFix)

            S = np.sum(hSig   .values()[xBinLower : xBinUpper, yBinLower : yBinUpper])
            B = np.sum(hBkgTot.values()[xBinLower : xBinUpper, yBinLower : yBinUpper])
            SByB = S / math.sqrt(B) if B > 0 else 0
            #print(f"(x, y): ({hSig.axes[0].centers[xBinFloat]}, {hSig.axes[1].centers[yBinFloat]}), BinFloat (x, y): ({xBinFloat}, {yBinFloat}), [{xBinLower} : {xBinUpper}, {yBinLower} : {yBinUpper}], S: {S} ({hSig.values()[xBinLower : xBinUpper, yBinLower : yBinUpper].shape}) {hSig.values()[xBinLower : xBinUpper, yBinLower : yBinUpper]}, B: {B}  ({hBkgTot.values()[xBinLower : xBinUpper, yBinLower : yBinUpper].shape}), SByB: {SByB} ")
            hSByB[xBinFloat, yBinFloat] = SByB 

    #print(f"\n\n\hSig.values() ({hSig.values().shape}):  {hSig.values().tolist() } ")
    #print(f"\n\n\nhSByB.values() ({hSByB.values().shape}):  {hSByB.values().tolist() } ")
    #print(f"\n\n\n {np.max(hSByB.values()) = },  {np.argmax(hSByB.values()) = },  {np.argmax(hSByB.values(), axis=0) = },  {np.argmax(hSByB.values(), axis=1) = } \n")

    #print(f"{hSByB.values().shape[0] = }, {hSByB.values().shape[1] = }, ")

    bin_SByBMax = np.argmax( hSByB.values() )
    xBin_SByBMax = int(bin_SByBMax / hSByB.values().shape[1])
    yBin_SByBMax = int(bin_SByBMax % hSByB.values().shape[1])
    SByB_max = hSByB.values()[xBin_SByBMax, yBin_SByBMax]
    #print(f"{bin_SByBMax = }, {xBin_SByBMax = }, {yBin_SByBMax = }, ")
    #print(f"{hSByB.values()[xBin_SByBMax, yBin_SByBMax] = }")


    x_SByBMax = hSByB.axes[0].centers[xBin_SByBMax]
    y_SByBMax = hSByB.axes[1].centers[yBin_SByBMax]
    
    #print(f"hSByB ({type(hSByB)}): {hSByB}")
    #print(f"hSByB.values() ({len(hSByB.values())}) ({type(hSByB.values())}): {hSByB.values()} ")

    #print(f"SByBMax: {np.max(hSByB.values())}, {bin_SByBMax = }, {xBin_SByBMax = }, {yBin_SByBMax = }, {x_SByBMax = }, {y_SByBMax = }")

    return hSByB, SByB_max, (x_SByBMax, y_SByBMax)

# %%
for selectionTag in selectionTags:
    for histo_name in histograms_dict.keys():
        histo_name_toUse = '%s_%s' % (histo_name, selectionTag)

        for sLableSig in MCSig_dict:
            MCSig_list = MCSig_dict[sLableSig]

            for systematic in systematics_list:
                
                xAxisRange = histograms_dict[histo_name][sXRange]      if sXRange    in histograms_dict[histo_name].keys() else None
                yAxisRange = histograms_dict[histo_name][sYRange]      if sYRange    in histograms_dict[histo_name].keys() else None
                xAxisLabel = histograms_dict[histo_name][sXLabel]      if sXLabel    in histograms_dict[histo_name].keys() else None
                yAxisLabel = histograms_dict[histo_name][sYLabel]      if sYLabel    in histograms_dict[histo_name].keys() else None
                xAxisScale = histograms_dict[histo_name][sXAxisScale]  if sXAxisScale    in histograms_dict[histo_name].keys() else None
                yAxisScale = histograms_dict[histo_name][sYAxisScale]  if sYAxisScale    in histograms_dict[histo_name].keys() else None                
                xAxisThrshType  = histograms_dict[histo_name][sXAxisThrshType] if sXAxisThrshType in histograms_dict[histo_name].keys() else None
                yAxisThrshType  = histograms_dict[histo_name][sYAxisThrshType] if sYAxisThrshType in histograms_dict[histo_name].keys() else None
                xAxisThrshSign  = '>=' if xAxisThrshType == ThrshTypes.LowerThrsh else '<='
                yAxisThrshSign  = '>=' if yAxisThrshType == ThrshTypes.LowerThrsh else '<='

                if printLevel >= 1:    print(f"\n\n {histo_name_toUse = }, {systematic = },  {sLableSig = }")




                hBkgTot = None
                if len(MCBkg_list) > 0:
                    hBkg_list = []
                    sBkg_list = []
                    nBkg_list = []
                    hBkg_integral_list = []
                    for dataset in MCBkg_list:
                        histo_name_full = 'evt/%s/%s_%s' % (dataset, histo_name_toUse, systematic)
                        #print(f"{histo_name_full = }")
                        #print(f"{fIpFile.keys() = }")
                        h = fIpFile[histo_name_full].to_hist()
                        
                        #print(f"{histo_name_full = } h ({type(h)}): {{h}}")
                        #h.show()
                        if hBkgTot == None:
                            hBkgTot = h
                        else:
                            hBkgTot = hBkgTot + h
                        
                        hBkg_list.append(h)
                        sBkg_list.append(dataset)
                        nBkg_list.append(np.sum(h.values()))
                        if printLevel >= 8:    print(f"{histo_name_full}: {np.sum(h.values())} ")

                    idx_nBkg_list_ascending = np.argsort(nBkg_list)
                    #print(f"{idx_nBkg_list_ascending = }")
                    #print(f"{hBkg_dict = }")
                    hBkg_dict_sorted = { sBkg_list[idx] : hBkg_list[idx]  for idx in idx_nBkg_list_ascending}
                    #print(f"{hBkg_dict_sorted = }")
                    hBkg_stack = hist.Stack.from_dict(hBkg_dict_sorted)


                hSigAvg = None
                hSig_stack = None
                if len(MCSig_list) > 0:
                    hSig_list = []
                    sSig_list = []
                    nSig_list = []
                    for dataset in MCSig_list:
                        histo_name_full = 'evt/%s/%s_%s' % (dataset, histo_name_toUse, systematic)
                        h = fIpFile[histo_name_full].to_hist()

                        hSig_list.append(h)
                        sSig_list.append(dataset)
                        nSig_list.append(np.sum(h.values()))

                        if hSigAvg == None:
                            hSigAvg = h
                        else:
                            hSigAvg = hSigAvg + h

                        #print(f"{dataset}: {np.sum(h.values())}, \n{h.values()}  \n{hSigAvg.values()}")
                        if printLevel >= 8:    print(f"{dataset}: {np.sum(h.values())} ")

                    idx_nSig_list_ascending = np.argsort(nSig_list)
                    #print(f"{idx_nSig_list_ascending = }")
                    #print(f"{hSig_dict = }")
                    hSig_dict_sorted = { sSig_list[idx] : hSig_list[idx]  for idx in idx_nSig_list_ascending}
                    #print(f"{hSig_dict_sorted = }")
                    hSig_stack = hist.Stack.from_dict(hSig_dict_sorted)  
                        
                    #print(f"hSigAvg_0: \n{hSigAvg.values()}")
                    # average of hSig
                    hSigAvg = hSigAvg / len(MCSig_list)
                    #print(f"{len(MCSig_list) = }")
                    #print(f"hSigAvg_1: \n{hSigAvg.values()}")

                #fig, ax = plt.subplots(ncols=1, nrows=2, figsize=(8,10), sharex='col', gridspec_kw={'height_ratios': [3, 1], 'hspace': 0})
                fig, ax = plt.subplots(ncols=1, nrows=1)

                # scan_SByB
                if printLevel >= 8:    print(f"{hSigAvg.axes = }")
                if printLevel >= 8:    print(f"{len(hSigAvg.axes) = }")
                if len(hSigAvg.axes) == 1:
                    #hSByB, SByB_max, cut_SByBMax, hSEffi, x_SEffi_map, x_SEffi_SByB_map = scan_SByB_over_H1D(
                    hSEffi, hBEffi, hSByB, hSBySB, hSignificanceZ, hCL, SByB_max, cut_SByBMax, x_SEffi_map, x_SEffi_SByB_map = scan_SByB_over_H1D(
                        hSig = hSigAvg, 
                        hBkgTot = hBkgTot, 
                        xAxisThrshType = xAxisThrshType,
                        xAxisRange = xAxisRange,
                        SEffiThrshs = SignalEfficiencyThresholdsForTaggerWPs,
                        BEffiThrshs = BackgroundMistagRateThresholdsForTaggerWPs)
                    if printLevel >= 8:    print(f"cut_SByBMax ({type(cut_SByBMax)}): {cut_SByBMax}")

                    sLable1 = 'S/sqrt(B). Max: %g for %s %g' % (SByB_max, xAxisThrshSign,cut_SByBMax)
                    '''hep.histplot(
                        hSByB.values(), bins=hSByB.axes[0].edges, #yerr=histosToOverlay_error_list[iHistoToOverlay], 
                        label=[sLable1], 
                        ax=ax, 
                        #histtype='errorbar', 
                        #density=normalize_histogram,
                        #color=marker_color_list[iHistoToOverlay], #'r',
                        #markersize=marker_size_list[iHistoToOverlay], #3,
                        #marker=marker_style_list[iHistoToOverlay] #marker_style_list
                    )'''      
                    h_values_list = []
                    sLable_list   = []
                    sLable_list0 = [
                        '%g.S/sqrt(B)' % (mu_forS), 
                        '%g.S/sqrt(%g.S+B)' % (mu_forS, mu_forS), 
                        'Z', 
                        'CL']
                    for ih_, h_ in enumerate([hSByB, hSBySB, hSignificanceZ, hCL]):
                        x_, y_ = GetHist1DMaxValue(h_) if sLable_list0[ih_] != 'CL' else GetHist1DMinValue(h_)
                        sLabel0 = sLable_list0[ih_] if sLable_list0[ih_] != 'CL' else 'CL x %g' %(sf_CL)
                        sExtreame = 'Max' if sLable_list0[ih_] != 'CL' else 'Min'
                        h_values_list.append( h_.values() )
                        sLable_list.append( '%s. %s: %g for %s %g' % (sLabel0, sExtreame, y_, xAxisThrshSign, x_) )

                    hep.histplot(
                        h_values_list, bins=hSByB.axes[0].edges, #yerr=histosToOverlay_error_list[iHistoToOverlay], 
                        label=sLable_list, 
                        ax=ax, 
                        #histtype='errorbar', 
                        #density=normalize_histogram,
                        #color=marker_color_list[iHistoToOverlay], #'r',
                        #markersize=marker_size_list[iHistoToOverlay], #3,
                        #marker=marker_style_list[iHistoToOverlay] #marker_style_list
                    )      
                    ax.set_ylabel(r'Significance metric')                    

                    ax2 = ax.twinx()
                    sLable2 = f"S efficiency"
                    hep.histplot(
                        hSEffi.values(), bins=hSEffi.axes[0].edges, #yerr=histosToOverlay_error_list[iHistoToOverlay], 
                        label=[sLable2], 
                        ax=ax2, 
                        #histtype='errorbar', 
                        #density=normalize_histogram,
                        color='c', #marker_color_list[iHistoToOverlay], #'r',
                        #markersize=marker_size_list[iHistoToOverlay], #3,
                        #marker=marker_style_list[iHistoToOverlay] #marker_style_list
                    )  
                    ax2.set_ylabel(r'Signal efficiency')  
                    ax2.set_ylim(0, 1)
                    ax2.yaxis.label.set_color('c')
                    tkw = dict(size=4, width=1.5)
                    ax2.tick_params(axis='y', colors='c', **tkw)

                    ax3 = ax.twinx()
                    ax3.spines.right.set_position(("axes", 1.2))
                    sLabel3 = f"Bkg mis-tag"
                    p3 = hep.histplot(
                        hBEffi.values(), bins=hSEffi.axes[0].edges, #yerr=histosToOverlay_error_list[iHistoToOverlay], 
                        label=[sLabel3], 
                        ax=ax3, 
                        #histtype='errorbar', 
                        #density=normalize_histogram,
                        color='b', #marker_color_list[iHistoToOverlay], #'r',
                        #markersize=marker_size_list[iHistoToOverlay], #3,
                        #marker=marker_style_list[iHistoToOverlay] #marker_style_list
                    )  
                    ax3.set_ylabel(r'Background mis-tag rate')
                    #print(f"\n\n\n {np.min(hBEffi.values()) = } \n\n\n")
                    y3min = max(np.min(hBEffi.values()), 1e-5)
                    ax3.set_ylim(y3min, 5e-2)
                    ax3.set_yscale('log', base=10)
                    ax3.yaxis.label.set_color('b')
                    ax3.tick_params(axis='y', colors='b', **tkw)

                    sTitle = 'S/sqrt(B) max: %g for %s %g' % (SByB_max, xAxisThrshSign,cut_SByBMax) 
                    sDetails = 'x: [S efficiency, B mis-tag, S/sqrt(B), S/sqrt(S+B), Z, CL] :'
                    for x in x_SEffi_SByB_map:
                        #sDetails += '\n%.4g: [%g, %g]' % (x, x_SEffi_SByB_map[x][0], x_SEffi_SByB_map[x][1])
                        #sScores_ = ['%.5g, ' % MLScore  for MLScore in x_SEffi_SByB_map[x]]
                        sScores_ = '['
                        for i_, MLScore in enumerate( x_SEffi_SByB_map[x] ):
                            if   i_ == 0: sScores_ += '%5.2g, ' % (MLScore)
                            elif i_ == 1: sScores_ += '%8.2g, ' % (MLScore)
                            else:         sScores_ += '%8.3g, ' % (MLScore)
                        sScores_ += ']'
                        sDetails += '\n%6.3g: %s' % (x, sScores_)

                    if printLevel >= 0:
                        print(f"\nHistogram: {histo_name_toUse,sLableSig}")
                        #print("%s \t %s \t %s \t %s \t %s \t %s" % ('', 'B_mistag', 'x_tagger', 'S_effi', 'Z', 'CL'))
                        table1 = OD([
                            ('x_tagger', {}),
                            ('S_effi', {}),
                            ('Z', {}),
                            ('CL', {}),                            
                        ])
                        for bgkMisTagRate in BackgroundMistagRateThresholdsForTaggerWPs:
                            # use that x which has x_SEffi_SByB_map[x] BgkMistagRate == bgkMisTagRate
                            x_toUse = None
                            diff_min = 999999.9
                            for x in x_SEffi_SByB_map:
                                #print(f"{bgkMisTagRate = }, {x_SEffi_SByB_map[x][1] = }, diff {abs(x_SEffi_SByB_map[x][1] - bgkMisTagRate)/bgkMisTagRate}, {x = }, {x_toUse = } ")
                                if abs(x_SEffi_SByB_map[x][1] - bgkMisTagRate) < diff_min: 
                                    x_toUse = x
                                    diff_min = abs(x_SEffi_SByB_map[x][1] - bgkMisTagRate)
                            #print(f"{x_toUse = }, {bgkMisTagRate = }, {x_SEffi_SByB_map[x_toUse] = }")
                            table1['x_tagger'][bgkMisTagRate] = '%.3f' % x_toUse
                            table1['S_effi'][bgkMisTagRate]   = '%.2f' % x_SEffi_SByB_map[x_toUse][0]
                            table1['Z'][bgkMisTagRate]        = '%.3g' % x_SEffi_SByB_map[x_toUse][4]
                            table1['CL'][bgkMisTagRate]       = '%.3g' % x_SEffi_SByB_map[x_toUse][5]
                            
                        sLine_toPrint = " \t"
                        for bgkMisTagRate in BackgroundMistagRateThresholdsForTaggerWPs[::-1]:
                            sLine_toPrint += "%.1f bgk \t" % (bgkMisTagRate*100)
                        print(sLine_toPrint)
                        for var_ in ['x_tagger', 'S_effi', 'Z', 'CL']:
                            sLine_toPrint = "%10s \t" % (var_)
                            for bgkMisTagRate in BackgroundMistagRateThresholdsForTaggerWPs[::-1]:
                                sLine_toPrint += "%10s \t" % (table1[var_][bgkMisTagRate])
                            print(sLine_toPrint)
                            


                elif len(hSigAvg.axes) == 2:    
                    hSByB, SByB_max, cut_SByBMax = scan_SByB_over_H2D(hSig = hSigAvg, hBkgTot = hBkgTot, xAxisThrshType = xAxisThrshType, yAxisThrshType = yAxisThrshType)
                    sTitle = 'S/sqrt(B) max: %g for (%s %g, %s %g)' % (SByB_max, xAxisThrshSign,cut_SByBMax[0], yAxisThrshSign,cut_SByBMax[1])

                    if printLevel >= 8:    print(f"cut_SByBMax ({type(cut_SByBMax)}): {cut_SByBMax}")

                    hep.hist2dplot(hSByB, ax=ax)

                

                if xAxisRange: ax.set_xlim(xAxisRange[0], xAxisRange[1])
                if yAxisRange: ax.set_ylim(yAxisRange[0], yAxisRange[1])
                if xAxisLabel: ax.set_xlabel(xAxisLabel)
                #if yAxisLabel: ax.set_ylabel(yAxisLabel)
                if yAxisScale and yAxisScale == 'log': ax.set_yscale('log', base=10)
                

                #print(f"{sTitle = }")
                #ax.legend(fontsize=11, loc='upper right', ncol=2)
                #ax.set_title(sTitle)
                #ax.legend()
                #ax2.legend()
                fig.legend(fontsize=11, loc='upper right', ncol=1, bbox_to_anchor=(0.9, 1.65))
                fig.text(0.1, 1.02, sDetails, fontsize=11, transform=ax.transAxes)
                fig.text(0.4, 0.9, '%s' % (sLableSig), fontsize=11, transform=ax.transAxes)

                sThrshSigns = ''
                if xAxisThrshType == ThrshTypes.LowerThrsh:
                    sThrshSigns += '_xThrshLower' 
                elif xAxisThrshType == ThrshTypes.UpperThrsh:
                    sThrshSigns += 'xThrshUpper'

                if yAxisThrshType == ThrshTypes.LowerThrsh:
                    sThrshSigns += '_yThrshLower' 
                elif yAxisThrshType == ThrshTypes.UpperThrsh:
                    sThrshSigns += 'yThrshUpper'

                #sSaveAs_toUse = '%s/%s_%s_%s_SByB%s.png' % (sOpDir,histo_name_toUse,sLableSig,systematic,sThrshSigns)
                sSaveAs_toUse = '%s/%s_%s' % (sOpDir,histo_name_toUse,sLableSig)

                fig.savefig(sSaveAs_toUse, transparent=False, dpi=80, bbox_inches="tight")
                plt.close(fig)
# Out:
# Histogram: ('hLeadingFatJetPNet_X4b_v1_Haa4b_vs_QCD_gg0lIncl', 'mA_50_60')
#  	0.1 bgk 	0.2 bgk 	0.3 bgk 	0.4 bgk 	0.5 bgk 	1.0 bgk 	2.0 bgk 	3.0 bgk 	4.0 bgk 	5.0 bgk
#   x_tagger 	     0.996 	     0.993 	     0.988 	     0.984 	     0.980 	     0.951 	     0.877 	     0.779 	     0.687 	     0.600
#     S_effi 	      0.23 	      0.34 	      0.45 	      0.51 	      0.56 	      0.71 	      0.83 	      0.88 	      0.90 	      0.92
#          Z 	      1.63 	      1.78 	      1.82 	       1.8 	      1.77 	      1.56 	      1.28 	      1.11 	     0.991 	     0.903
#         CL 	      1.25 	      1.14 	      1.11 	      1.12 	      1.14 	      1.29 	      1.57 	      1.81 	      2.03 	      2.22
#
# Histogram: ('hLeadingFatJetPNet_X4b_v2a_Haa4b_score_gg0lIncl', 'mA_50_60')
#  	0.1 bgk 	0.2 bgk 	0.3 bgk 	0.4 bgk 	0.5 bgk 	1.0 bgk 	2.0 bgk 	3.0 bgk 	4.0 bgk 	5.0 bgk
# ...
